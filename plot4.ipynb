# %%
import pandas as pd
import numpy as np
import scipy as sp

# %%
data = pd.read_csv('data/fj1.csv', dtype={"resolution": str, "gsubname2":str, "gname3":str, "gsubname3":str, "claimmode3_txt":str, "weaptype4_txt":str, "weapsubtype4_txt":str, "divert":str, "kidhijcountry":str})

# %%
data = data[['weaptype1','nkill']]

# %%
data['nkill'].fillna(0.0, inplace = True)

# %%
data
# Out:
#         weaptype1  nkill
# 0               5  104.0
# 1               6    0.0
# 2               5    1.0
# 3               6    0.0
# 4               5    0.0
# 5               6    0.0
# 6               6    0.0
# 7               6    0.0
# 8               6    0.0
# 9               5   14.0
# 10              5   56.0
# 11              5   13.0
# 12              6    0.0
# 13              9    0.0
# 14              9    0.0
# 15              6    0.0
# 16              9    0.0
# 17              9    0.0
# 18              6    1.0
# 19              6    0.0
# 20              9   26.0
# 21              6    2.0
# 22              5    2.0
# 23              6    0.0
# 24              5    1.0
# 25              5   25.0
# 26              6    0.0
# 27              6  200.0
# 28              6    0.0
# 29              6    0.0
# ...           ...    ...
# 114153          8    1.0
# 114154          6    0.0
# 114155          6    0.0
# 114156          5    0.0
# 114157          5    0.0
# ...

# %%
df = data.groupby(by=['weaptype1'])['nkill'].sum()
df
# Out:
# weaptype1
# 1          9.0
# 2        510.0
# 3          2.0
# 5      89450.0
# 6     149630.0
# 7          1.0
# 8       3787.0
# 9       5076.0
# 10      3126.0
# 11        52.0
# 12       107.0
# 13     27795.0
# Name: nkill, dtype: float64

# %%
submission=pd.DataFrame({"weaptype1":df.index,"sum of nkill":df})

submission.to_csv('data/plot4.csv', index=False)
