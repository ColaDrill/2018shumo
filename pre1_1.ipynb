# %%
import pandas as pd
import numpy as np
import scipy as sp

# %%
data=pd.read_csv('data/fj1.csv', dtype={"resolution": str, "gsubname2":str, "gname3":str, "gsubname3":str, "claimmode3_txt":str, "weaptype4_txt":str, "weapsubtype4_txt":str, "divert":str, "kidhijcountry":str})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114183 entries, 0 to 114182
# Columns: 135 entries, eventid to related
# dtypes: float64(54), int64(23), object(58)
# memory usage: 117.6+ MB

# %%
def positive(x):
    if x > 0 :
        return x
    else:
        return 0;

# %%
#data=data.fillna(-1)
#data=data.apply(positive)

# %%
data = data[data.doubtterr == 0]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95710 entries, 1 to 114182
# Columns: 135 entries, eventid to related
# dtypes: float64(54), int64(23), object(58)
# memory usage: 99.3+ MB

# %%
pd_feature = ['propextent', 'region','crit1', 'crit2', 'crit3', 'success', 'suicide', 'attacktype1', 'targtype1', 'nperps', 'weaptype1', 'ransom']

data_pd=data[pd_feature]

# %%
data['propextent'].fillna(4, inplace = True)
data_pd.loc[ data_pd['propextent'] == -9, 'propextent'] = 4
# Out:
# C:\Users\caijiayue\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
data_pd['nperps'].fillna(5, inplace = True)
data_pd.loc[ (data_pd['nperps'] >= 1) & (data_pd['nperps'] < 10), 'nperps'] = 1
data_pd.loc[ (data_pd['nperps'] >= 10) & (data_pd['nperps'] < 100), 'nperps'] = 2
data_pd.loc[ (data_pd['nperps'] >= 100) & (data_pd['nperps'] < 500), 'nperps'] = 3
data_pd.loc[ data_pd['nperps'] >= 500, 'nperps'] = 4
data_pd.loc[ data_pd['nperps'] == -99, 'nperps'] = 5
data_pd['nperps'] = data_pd['nperps'].astype(int)
# Out:
# C:\Users\caijiayue\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:4355: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\caijiayue\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# C:\Users\caijiayue\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
data_pd['nperps'].fillna(5, inplace = True)
data_pd['nperps'] = data_pd['nperps'].astype(int)
data_pd.loc[ (data_pd['nperps'] >= 1) & (data_pd['nperps'] < 10), 'nperps'] = 1
data_pd.loc[ (data_pd['nperps'] >= 10) & (data_pd['nperps'] < 100), 'nperps'] = 2
data_pd.loc[ (data_pd['nperps'] >= 100) & (data_pd['nperps'] < 500), 'nperps'] = 3
data_pd.loc[ data_pd['nperps'] >= 500, 'nperps'] = 4
data_pd.loc[ data_pd['nperps'] == -99, 'nperps'] = 5
# Out:
# C:\Users\caijiayue\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:4355: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\caijiayue\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\caijiayue\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
data_pd.loc[ data_pd['ransom'] == -9, 'ransom'] = 3
data_pd['ransom'].fillna(3, inplace = True)
# Out:
# C:\Users\caijiayue\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# C:\Users\caijiayue\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:4355: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
data_pd
# Out:
#         propextent  region  crit1  crit2  crit3  success  suicide  \
# 1              NaN       9      1      1      1        1        0
# 2              NaN       8      1      1      1        1        0
# 3              3.0      10      1      1      1        1        0
# 4              NaN      10      1      1      1        0        0
# 5              NaN       9      1      1      1        1        0
# 6              NaN       9      1      1      1        1        0
# 7              NaN       8      1      1      1        0        0
# 8              4.0       3      1      1      1        1        0
# 9              NaN      11      1      1      1        1        0
# 10             NaN      11      1      1      1        1        0
# 12             3.0       3      1      1      1        1        0
# 13             NaN      10      1      1      1        1        0
# 14             NaN      10      1      1      1        1        0
# 15             NaN       8      1      1      1        0        0
# 16             NaN      10      1      1      1        1        0
# 17             NaN      10      1      1      1        1        0
# 18             NaN       8      1      1      1        1        0
# 19             4.0       6      1      1      1        1        0
# 20             NaN      10      1      1      1        1        0
# 21             NaN      10      1      1      1        1        0
# 23             4.0       8      1      1      1        1        0
# 24             NaN       8      1      1      1        1        0
# 25             NaN       6      1      1      1        1        0
# 26             4.0      10      1      1      1        1        0
# 27             4.0      10      1      1      1        1        0
# 28             4.0       9      1      1      1        1        0
# 29             4.0       9      1      1      1        1        0
# 30             4.0       9      1      1      1        1        0
# 31             NaN      10      1      1      1        1        0
# 33             NaN      10      1      1      1        1        0
# ...            ...     ...    ...    ...    ...      ...      ...
# 114142         NaN       6      1      1      1        0        0
# 114144         NaN       5      1      1      1        1        0
# 114145         3.0      11      1      1      1        1        1
# 114146         3.0      11      1      1      1        1        0
# 114148         3.0      11      1      1      1        1        0
# 114149         4.0      11      1      1      1        1        0
# 114150         4.0      11      1      1      1        1        0
# 114151         3.0      11      1      1      1        1        0
# 114153         3.0       6      1      1      1        1        0
# 114155         NaN       6      1      1      1        1        0
# 114156         NaN       8      1      1      1        1        0
# 114157         3.0       6      1      1      1        1        0
# 114158         3.0      11      1      1      1        1        0
# 114161         NaN      10      1      1      1        1        0
# 114162         NaN      10      1      1      1        1        0
# 114163         NaN      10      1      1      1        1        0
# 114164         NaN       6      1      1      1        1        1
# 114165         NaN       6      1      1      1        1        0
# 114167         4.0      11      1      1      1        1        0
# 114168         3.0       6      1      1      1        1        0
# 114169         3.0       5      1      1      1        1        0
# 114170         NaN       5      1      1      1        1        0
# 114173         3.0       5      1      1      1        1        0
# 114174         4.0       8      1      1      1        1        0
# 114175         NaN       6      1      1      1        1        0
# 114176         NaN       6      1      1      1        1        0
# 114177         3.0       6      1      1      1        1        0
# 114180         4.0       5      1      1      1        1        0
# 114181         NaN       6      1      1      1        0        0
# 114182         NaN       5      1      1      1        0        0
#
#         attacktype1  targtype1  nperps  weaptype1  ransom
# 1                 3         19       1          6     3.0
# 2                 2         14       1          5     3.0
# 3                 3          7       1          6     3.0
# 4                 2         14       1          5     3.0
# 5                 3          3       1          6     3.0
# 6                 3          3       1          6     3.0
# 7                 3          3       1          6     3.0
# 8                 3         10       1          6     3.0
# 9                 2         14       1          5     3.0
# 10                2         14       1          5     3.0
# 12                3          1       1          6     3.0
# 13                2         14       1          9     3.0
# 14                2         14       1          9     3.0
# 15                3         14       1          6     3.0
# 16                2         14       1          9     3.0
# 17                2         14       1          9     3.0
# 18                3          2       1          6     3.0
# 19                3         14       1          6     3.0
# 20                2         14       1          9     0.0
# 21                3         14       1          6     3.0
# 23                3          2       1          6     3.0
# 24                2         14       1          5     3.0
# 25                2         14       1          5     3.0
# 26                3          1       1          6     3.0
# 27                3         15       1          6     3.0
# 28                3          2       1          6     3.0
# 29                3          2       1          6     3.0
# 30                3          2       1          6     3.0
# 31                3         14       1          6     3.0
# 33                3         14       1          6     3.0
# ...             ...        ...     ...        ...     ...
# 114142            3         20       1          6     3.0
# 114144            3         14       1          6     3.0
# 114145            3          1       1          6     3.0
# 114146            9         14       1         13     3.0
# 114148            2         14       1          5     3.0
# 114149            2          3       1          5     3.0
# 114150            3         16       1          6     3.0
# 114151            7          1       1          5     3.0
# 114153            7         15       1          8     3.0
# 114155            3          3       1          6     3.0
# 114156            2         14       1          5     3.0
# 114157            7          1       1          5     3.0
# 114158            7         14       1         13     3.0
# 114161            3          1       1          6     3.0
# 114162            9          3       1         13     3.0
# 114163            3         14       1          6     3.0
# 114164            2          3       1          6     3.0
# 114165            3         14       1          6     3.0
# 114167            3          4       1          6     3.0
# 114168            3          3       1          6     3.0
# 114169            7         14       1          5     3.0
# 114170            3          1       1          6     3.0
# 114173            3          3       1          6     3.0
# 114174            7         14       1          8     3.0
# 114175            2         17       1          5     3.0
# 114176            6          2       1          5     0.0
# 114177            3          1       1          6     3.0
# 114180            7         14       1          8     3.0
# 114181            3          2       1          6     3.0
# 114182            3         20       1          6     3.0
#
# [95710 rows x 12 columns]

# %%
data_pd = data_pd.dropna()

# %%
data_pd
# Out:
#         propextent  region  crit1  crit2  crit3  success  suicide  \
# 3              3.0      10      1      1      1        1        0
# 8              4.0       3      1      1      1        1        0
# 12             3.0       3      1      1      1        1        0
# 19             4.0       6      1      1      1        1        0
# 23             4.0       8      1      1      1        1        0
# 26             4.0      10      1      1      1        1        0
# 27             4.0      10      1      1      1        1        0
# 28             4.0       9      1      1      1        1        0
# 29             4.0       9      1      1      1        1        0
# 30             4.0       9      1      1      1        1        0
# 35             3.0      10      1      1      1        1        0
# 36             3.0       9      1      1      1        1        0
# 38             3.0       9      1      1      1        1        0
# 39             3.0       8      1      1      1        1        0
# 43             3.0       5      1      1      1        1        0
# 45             3.0       5      1      1      1        1        0
# 55             3.0      10      1      1      1        1        0
# 56             3.0      10      1      1      1        1        0
# 63             3.0       6      1      1      1        1        0
# 64             3.0       6      1      1      1        1        1
# 66             3.0       6      1      1      1        1        0
# 67             3.0       6      1      1      1        1        0
# 69             3.0       8      1      1      1        1        0
# 71             3.0       6      1      1      1        1        1
# 73             3.0       8      1      1      1        1        0
# 80             3.0       1      1      1      1        1        0
# 84             3.0       4      1      1      1        1        0
# 85             3.0       9      1      1      1        1        0
# 88             4.0      10      1      1      1        1        0
# 91             3.0       8      1      1      1        1        0
# ...            ...     ...    ...    ...    ...      ...      ...
# 114084         3.0      10      1      1      1        1        0
# 114089         3.0       6      1      1      1        1        0
# 114090         4.0       6      1      1      1        1        0
# 114091         3.0       6      1      1      1        1        0
# 114098         3.0       6      1      1      1        1        0
# 114099         3.0      10      1      1      1        1        0
# 114101         3.0       9      1      1      1        1        0
# 114107         3.0       6      1      1      1        1        0
# 114110         3.0       6      1      1      1        1        0
# 114116         4.0      10      1      1      1        1        1
# 114117         3.0      10      1      1      1        1        0
# 114119         3.0       6      1      1      1        1        0
# 114123         4.0      11      1      1      1        1        0
# 114141         3.0       6      1      1      1        1        0
# 114145         3.0      11      1      1      1        1        1
# 114146         3.0      11      1      1      1        1        0
# 114148         3.0      11      1      1      1        1        0
# 114149         4.0      11      1      1      1        1        0
# 114150         4.0      11      1      1      1        1        0
# 114151         3.0      11      1      1      1        1        0
# 114153         3.0       6      1      1      1        1        0
# 114157         3.0       6      1      1      1        1        0
# 114158         3.0      11      1      1      1        1        0
# 114167         4.0      11      1      1      1        1        0
# 114168         3.0       6      1      1      1        1        0
# 114169         3.0       5      1      1      1        1        0
# 114173         3.0       5      1      1      1        1        0
# 114174         4.0       8      1      1      1        1        0
# 114177         3.0       6      1      1      1        1        0
# 114180         4.0       5      1      1      1        1        0
#
#         attacktype1  targtype1  nperps  weaptype1  ransom
# 3                 3          7       1          6     3.0
# 8                 3         10       1          6     3.0
# 12                3          1       1          6     3.0
# 19                3         14       1          6     3.0
# 23                3          2       1          6     3.0
# 26                3          1       1          6     3.0
# 27                3         15       1          6     3.0
# 28                3          2       1          6     3.0
# 29                3          2       1          6     3.0
# 30                3          2       1          6     3.0
# 35                3         15       1          6     0.0
# 36                3          2       1          6     3.0
# 38                3         10       1          6     3.0
# 39                7          1       1          8     3.0
# 43                7          2       1          5     3.0
# 45                3          1       1          6     3.0
# 55                3          8       1          6     0.0
# 56                3         14       1          6     0.0
# 63                3         19       1          6     3.0
# 64                3         15       1          6     3.0
# 66                3         19       1          6     3.0
# 67                2         14       1          9     3.0
# 69                7         14       1          8     3.0
# 71                3         15       1          6     3.0
# 73                7         14       1          8     3.0
# 80                3          5       1          6     3.0
# 84                3          6       1          6     3.0
# 85                3         19       1          6     3.0
# 88                3         14       1          6     0.0
# 91                3         14       1          6     3.0
# ...             ...        ...     ...        ...     ...
# 114084            2          3       1          6     3.0
# 114089            3         20       1          6     3.0
# 114090            3         21       1          6     3.0
# 114091            3          8       1          6     3.0
# 114098            7          1       1          8     3.0
# 114099            3          3       1          6     3.0
# 114101            8         12       1          9     3.0
# 114107            5          1       1          5     0.0
# 114110            3          3       1          6     3.0
# 114116            3         15       1          6     3.0
# 114117            2          1       1          5     3.0
# 114119            3         15       1          6     3.0
# 114123            2          3       1          5     3.0
# 114141            3         14       1          6     3.0
# 114145            3          1       1          6     3.0
# 114146            9         14       1         13     3.0
# 114148            2         14       1          5     3.0
# 114149            2          3       1          5     3.0
# 114150            3         16       1          6     3.0
# 114151            7          1       1          5     3.0
# 114153            7         15       1          8     3.0
# 114157            7          1       1          5     3.0
# 114158            7         14       1         13     3.0
# 114167            3          4       1          6     3.0
# 114168            3          3       1          6     3.0
# 114169            7         14       1          5     3.0
# 114173            3          3       1          6     3.0
# 114174            7         14       1          8     3.0
# 114177            3          1       1          6     3.0
# 114180            7         14       1          8     3.0
#
# [41475 rows x 12 columns]

# %%
data_pd.to_csv('data/data_pd.csv', index=False)
